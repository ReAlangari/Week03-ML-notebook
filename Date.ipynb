# %%
import pandas as pd
import os
import kagglehub


path = kagglehub.dataset_download("muratkokludataset/date-fruit-datasets")


for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith(".xlsx"):
            df_dates = pd.read_excel(os.path.join(root, file))
            break


X_clustering = df_dates.drop('Class', axis=1)
